# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
data = pd.read_csv('store_data.csv',header = None);
data.head()
# Out:
#         0          1       2          3     4       5          6
# 0    milk      bread  butter     yogurt  curd  cheese  chocolate
# 1  butter     yogurt    curd        NaN   NaN     NaN        NaN
# 2  cheese  chocolate     NaN        NaN   NaN     NaN        NaN
# 3    milk      bread  butter     yogurt   NaN     NaN        NaN
# 4   bread     butter  yogurt  chocolate   NaN     NaN        NaN

# %%
data.shape
# Out:
# (10, 7)

# %%
records = [];
for i in range(0,10):
    records.append([str(data.values[i,j]) for j in range(0,7 )]);
association_rules = apriori(records,min_support = 0.0050 ,min_cofidence = 0.2,min_lift = 2, min_length = 2)
association_results = list(association_rules);

# %%
for item in association_results:
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
    
print(len(association_results))
#print(association_results)
# Out:
# Rule: butter -> bread
# Support: 0.4
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> cheese
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> bread
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> bread
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> yogurt
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: cheese -> bread
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> bread
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> cheese
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> cheese
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: butter -> cheese
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> cheese
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> cheese
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> nan
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> yogurt
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> yogurt
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> cheese
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: cheese -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: cheese -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: nan -> cheese
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: nan -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> cheese
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: cheese -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: nan -> cheese
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: cheese -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: chocolate -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: chocolate -> milk
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: chocolate -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> milk
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: milk -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: chocolate -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: chocolate -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: chocolate -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: chocolate -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: chocolate -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: chocolate -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> milk
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: chocolate -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# 93
